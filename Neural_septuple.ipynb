# %% [markdown]
# # Neural Septuple

# %%
import numpy as np
import torch
import matplotlib.pyplot as plt

# %%
class neural_septuple:

  def __init__(self, num_input_vec, num_output_vec):

    self.bias = True
    
    self.num_input_vec = num_input_vec
    self.num_output_vec = num_output_vec
    self.hidden_layer = 2
    self.num_hidden_layer_1_vec = 8
    self.num_hidden_layer_2_vec = 1
    #self.num_hidden_layer_3_vec = 2
    #self.num_hidden_layer_4_vec = 2
    self.num_total_vec = self.num_input_vec + self.num_output_vec + self.num_hidden_layer_1_vec + self.num_hidden_layer_2_vec #+ self.num_hidden_layer_3_vec #+ self.num_hidden_layer_4_vec
    self.idx_layer = [self.num_input_vec,8,1,self.num_output_vec]
    #self.state_vec = torch.tensor([5,6,0,0,0,0,7]).unsqueeze(dim=0).T
    
    p_in = torch.eye(self.num_input_vec)
    p_out = torch.eye(self.num_output_vec)
    p1 = torch.zeros((self.num_total_vec, self.num_total_vec))
    p2 = torch.zeros((self.num_total_vec, self.num_total_vec))

    p1[:self.num_input_vec, :self.num_input_vec] = p_in
    p2[-self.num_output_vec: , -self.num_output_vec:] = p_out
    self.p_in = p1 
    self.p_out = p2 
    I = torch.eye(self.num_total_vec)
    self.p_bulk = I - (self.p_in + self.p_out)
    self.p = self.p_in + self.p_out

  def create_state_vec(self,x,y):
    x = x.unsqueeze(dim=1)
    y = y.unsqueeze(dim=1)
    state = torch.zeros((sum(self.idx_layer), 1))
    state[:len(x)] = x
    state[-len(y):] = y
    self.state_vec = state
    self.input_vec = self.p_in @ self.state_vec.type(torch.float)
    self.output_vec = self.p_out @ self.state_vec.type(torch.float)


  def create_weight_matrix(self):
    count = 0
    self.final = []
    self.vec_idx = torch.tensor([i for i in range(self.num_total_vec)])
    for i in self.idx_layer:
      l = []
      for j in range(count, count+i):
        l.append(self.vec_idx[j])
      count += i
      self.final.append(l)
    self.weights = torch.zeros((self.num_total_vec, self.num_total_vec))
    i, j = 0,1
    while j < len(self.final):
      for row in self.final[i]:
        for col in self.final[j]:
          self.weights[col, row] = torch.randn((1,1))
      i += 1
      j += 1
    #self.weights[:, -1] = torch.randn((1,1))
    self.bias = torch.zeros((self.num_total_vec, 1))
    for i in range(self.num_input_vec, self.num_total_vec-self.num_output_vec):
        self.bias[i,0] = torch.randn((1,1))
    self.weights.requires_grad = True
    self.bias.requires_grad = True



  def feed_forword(self, x):
    first = x
    self.weights.requires_grad = True
    self.bias.requires_grad = True
    for i in range(self.hidden_layer):
      x = torch.tanh((self.weights @ x) + self.bias) + first
      #print(x)
    x = (self.weights @ x) + self.bias + first
    return x 
      


  def backword_feed(self, error):
    #print('LOSS: ', error)
    error.backward()
    for i in range(self.num_total_vec):
      for j in range(self.num_total_vec):
        if not self.weights[i,j]:
          self.weights.grad[i,j] = 0
    #print(self.weights.grad, '####')
    with torch.no_grad():
      self.weights = self.weights - (0.0001 * self.weights.grad)
      self.bias = self.bias - (0.0001 * self.bias.grad)
    #print(self.weights.grad, '****')
    if self.weights.grad:
      self.weights.grad.zero_()
    if self.bias.grad:
      self.bias.grad.zero_()


  def loss(self, pred, actual):
    return (pred - actual).T @ self.p_out @ (pred - actual)
        
    

  def create_projection_matrix(self, x):
    A = np.linalg.inv(x.T @ x)
    return x @ A @ x.T

# %%
x = torch.randn(5000, 3)
y = torch.zeros((5000,1))
for i in range(len(x)):
  y[i] = ((x[i][0]**3) * 1.2 + (x[i][1]**2) * 2.3 +x[i][2] * 1)

# %%
batch_size = 1
epochs = 100
a = neural_septuple(3,1)
loss = []
epoch = []

for i in range(epochs):
  print('EPOCHS: {} ***************'.format(i+1))
  count = 0
  error_count = 0
  for j in range(len(x)):
    a.create_state_vec(x[j],y[j])
    if i == 0 and j == 0:
      a.create_weight_matrix()
    pred = a.feed_forword(a.input_vec)
    error = (pred - a.state_vec).T @ a.p_out @ (pred - a.state_vec)
    #print(error)
    if (j+1) % batch_size == 0:
      error_count += error
      count += error
      error_count = error_count / batch_size
      #print('LOSS: ', error_count)
      a.backword_feed(error_count)
      error_count = 0
    else:
      with torch.no_grad():
        error_count += error
        count += error 
      #print(error_count)
  print('ERROR:{} '.format(i+1), count/5000)
  loss.append(count/5000)
  epoch.append(i)
# Out:
# EPOCHS: 1 ***************
# ERROR:1  tensor([[35.5064]], grad_fn=<DivBackward0>)
# EPOCHS: 2 ***************
# ERROR:2  tensor([[27.6235]], grad_fn=<DivBackward0>)
# EPOCHS: 3 ***************
# ERROR:3  tensor([[22.0227]], grad_fn=<DivBackward0>)
# EPOCHS: 4 ***************
# ERROR:4  tensor([[18.6134]], grad_fn=<DivBackward0>)
# EPOCHS: 5 ***************
# ERROR:5  tensor([[16.6140]], grad_fn=<DivBackward0>)
# EPOCHS: 6 ***************
# ERROR:6  tensor([[15.0346]], grad_fn=<DivBackward0>)
# EPOCHS: 7 ***************
# ERROR:7  tensor([[13.6392]], grad_fn=<DivBackward0>)
# EPOCHS: 8 ***************
# ERROR:8  tensor([[12.5113]], grad_fn=<DivBackward0>)
# EPOCHS: 9 ***************
# ERROR:9  tensor([[11.6155]], grad_fn=<DivBackward0>)
# EPOCHS: 10 ***************
# ERROR:10  tensor([[10.8767]], grad_fn=<DivBackward0>)
# EPOCHS: 11 ***************
# ERROR:11  tensor([[10.2538]], grad_fn=<DivBackward0>)
# EPOCHS: 12 ***************
# ERROR:12  tensor([[9.7133]], grad_fn=<DivBackward0>)
# EPOCHS: 13 ***************
# ERROR:13  tensor([[9.2380]], grad_fn=<DivBackward0>)
# EPOCHS: 14 ***************
# ERROR:14  tensor([[8.8213]], grad_fn=<DivBackward0>)
# EPOCHS: 15 ***************
# ERROR:15  tensor([[8.4592]], grad_fn=<DivBackward0>)
# EPOCHS: 16 ***************
# ERROR:16  tensor([[8.1450]], grad_fn=<DivBackward0>)
# EPOCHS: 17 ***************
# ERROR:17  tensor([[7.8707]], grad_fn=<DivBackward0>)
# EPOCHS: 18 ***************
# ERROR:18  tensor([[7.6287]], grad_fn=<DivBackward0>)
# EPOCHS: 19 ***************
# ERROR:19  tensor([[7.4135]], grad_fn=<DivBackward0>)
# EPOCHS: 20 ***************
# ERROR:20  tensor([[7.2210]], grad_fn=<DivBackward0>)
# EPOCHS: 21 ***************
# ERROR:21  tensor([[7.0482]], grad_fn=<DivBackward0>)
# EPOCHS: 22 ***************
# ERROR:22  tensor([[6.8925]], grad_fn=<DivBackward0>)
# EPOCHS: 23 ***************
# ERROR:23  tensor([[6.7515]], grad_fn=<DivBackward0>)
# EPOCHS: 24 ***************
# ERROR:24  tensor([[6.6230]], grad_fn=<DivBackward0>)
# EPOCHS: 25 ***************
# ERROR:25  tensor([[6.5044]], grad_fn=<DivBackward0>)
# EPOCHS: 26 ***************
# ERROR:26  tensor([[6.3928]], grad_fn=<DivBackward0>)
# EPOCHS: 27 ***************
# ERROR:27  tensor([[6.2846]], grad_fn=<DivBackward0>)
# EPOCHS: 28 ***************
# ERROR:28  tensor([[6.1749]], grad_fn=<DivBackward0>)
# EPOCHS: 29 ***************
# ERROR:29  tensor([[6.0572]], grad_fn=<DivBackward0>)
# EPOCHS: 30 ***************
# ERROR:30  tensor([[5.9239]], grad_fn=<DivBackward0>)
# EPOCHS: 31 ***************
# ERROR:31  tensor([[5.7698]], grad_fn=<DivBackward0>)
# EPOCHS: 32 ***************
# ERROR:32  tensor([[5.5967]], grad_fn=<DivBackward0>)
# EPOCHS: 33 ***************
# ERROR:33  tensor([[5.4141]], grad_fn=<DivBackward0>)
# EPOCHS: 34 ***************
# ERROR:34  tensor([[5.2311]], grad_fn=<DivBackward0>)
# EPOCHS: 35 ***************
# ERROR:35  tensor([[5.0530]], grad_fn=<DivBackward0>)
# EPOCHS: 36 ***************
# ERROR:36  tensor([[4.8831]], grad_fn=<DivBackward0>)
# EPOCHS: 37 ***************
# ERROR:37  tensor([[4.7239]], grad_fn=<DivBackward0>)
# EPOCHS: 38 ***************
# ERROR:38  tensor([[4.5770]], grad_fn=<DivBackward0>)
# EPOCHS: 39 ***************
# ERROR:39  tensor([[4.4424]], grad_fn=<DivBackward0>)
# EPOCHS: 40 ***************
# ERROR:40  tensor([[4.3196]], grad_fn=<DivBackward0>)
# EPOCHS: 41 ***************
# ERROR:41  tensor([[4.2071]], grad_fn=<DivBackward0>)
# EPOCHS: 42 ***************
# ERROR:42  tensor([[4.1040]], grad_fn=<DivBackward0>)
# EPOCHS: 43 ***************
# ERROR:43  tensor([[4.0088]], grad_fn=<DivBackward0>)
# EPOCHS: 44 ***************
# ERROR:44  tensor([[3.9208]], grad_fn=<DivBackward0>)
# EPOCHS: 45 ***************
# ERROR:45  tensor([[3.8390]], grad_fn=<DivBackward0>)
# EPOCHS: 46 ***************
# ERROR:46  tensor([[3.7626]], grad_fn=<DivBackward0>)
# EPOCHS: 47 ***************
# ERROR:47  tensor([[3.6911]], grad_fn=<DivBackward0>)
# EPOCHS: 48 ***************
# ERROR:48  tensor([[3.6239]], grad_fn=<DivBackward0>)
# EPOCHS: 49 ***************
# ERROR:49  tensor([[3.5604]], grad_fn=<DivBackward0>)
# EPOCHS: 50 ***************
# ERROR:50  tensor([[3.5002]], grad_fn=<DivBackward0>)
# EPOCHS: 51 ***************
# ERROR:51  tensor([[3.4430]], grad_fn=<DivBackward0>)
# EPOCHS: 52 ***************
# ERROR:52  tensor([[3.3885]], grad_fn=<DivBackward0>)
# EPOCHS: 53 ***************
# ERROR:53  tensor([[3.3362]], grad_fn=<DivBackward0>)
# EPOCHS: 54 ***************
# ERROR:54  tensor([[3.2861]], grad_fn=<DivBackward0>)
# EPOCHS: 55 ***************
# ERROR:55  tensor([[3.2379]], grad_fn=<DivBackward0>)
# EPOCHS: 56 ***************
# ERROR:56  tensor([[3.1914]], grad_fn=<DivBackward0>)
# EPOCHS: 57 ***************
# ERROR:57  tensor([[3.1466]], grad_fn=<DivBackward0>)
# EPOCHS: 58 ***************
# ERROR:58  tensor([[3.1031]], grad_fn=<DivBackward0>)
# EPOCHS: 59 ***************
# ERROR:59  tensor([[3.0611]], grad_fn=<DivBackward0>)
# EPOCHS: 60 ***************
# ERROR:60  tensor([[3.0204]], grad_fn=<DivBackward0>)
# EPOCHS: 61 ***************
# ERROR:61  tensor([[2.9809]], grad_fn=<DivBackward0>)
# EPOCHS: 62 ***************
# ERROR:62  tensor([[2.9425]], grad_fn=<DivBackward0>)
# EPOCHS: 63 ***************
# ERROR:63  tensor([[2.9052]], grad_fn=<DivBackward0>)
# EPOCHS: 64 ***************
# ERROR:64  tensor([[2.8689]], grad_fn=<DivBackward0>)
# EPOCHS: 65 ***************
# ERROR:65  tensor([[2.8337]], grad_fn=<DivBackward0>)
# EPOCHS: 66 ***************
# ERROR:66  tensor([[2.7994]], grad_fn=<DivBackward0>)
# EPOCHS: 67 ***************
# ERROR:67  tensor([[2.7659]], grad_fn=<DivBackward0>)
# EPOCHS: 68 ***************
# ERROR:68  tensor([[2.7334]], grad_fn=<DivBackward0>)
# EPOCHS: 69 ***************
# ERROR:69  tensor([[2.7016]], grad_fn=<DivBackward0>)
# EPOCHS: 70 ***************
# ERROR:70  tensor([[2.6706]], grad_fn=<DivBackward0>)
# EPOCHS: 71 ***************
# ERROR:71  tensor([[2.6404]], grad_fn=<DivBackward0>)
# EPOCHS: 72 ***************
# ERROR:72  tensor([[2.6108]], grad_fn=<DivBackward0>)
# EPOCHS: 73 ***************
# ERROR:73  tensor([[2.5819]], grad_fn=<DivBackward0>)
# EPOCHS: 74 ***************
# ERROR:74  tensor([[2.5536]], grad_fn=<DivBackward0>)
# EPOCHS: 75 ***************
# ERROR:75  tensor([[2.5260]], grad_fn=<DivBackward0>)
# EPOCHS: 76 ***************
# ERROR:76  tensor([[2.4989]], grad_fn=<DivBackward0>)
# EPOCHS: 77 ***************
# ERROR:77  tensor([[2.4725]], grad_fn=<DivBackward0>)
# EPOCHS: 78 ***************
# ERROR:78  tensor([[2.4466]], grad_fn=<DivBackward0>)
# EPOCHS: 79 ***************
# ERROR:79  tensor([[2.4212]], grad_fn=<DivBackward0>)
# EPOCHS: 80 ***************
# ERROR:80  tensor([[2.3964]], grad_fn=<DivBackward0>)
# EPOCHS: 81 ***************
# ERROR:81  tensor([[2.3722]], grad_fn=<DivBackward0>)
# EPOCHS: 82 ***************
# ERROR:82  tensor([[2.3484]], grad_fn=<DivBackward0>)
# EPOCHS: 83 ***************
# ERROR:83  tensor([[2.3251]], grad_fn=<DivBackward0>)
# EPOCHS: 84 ***************
# ERROR:84  tensor([[2.3023]], grad_fn=<DivBackward0>)
# EPOCHS: 85 ***************
# ERROR:85  tensor([[2.2800]], grad_fn=<DivBackward0>)
# EPOCHS: 86 ***************
# ERROR:86  tensor([[2.2581]], grad_fn=<DivBackward0>)
# EPOCHS: 87 ***************
# ERROR:87  tensor([[2.2367]], grad_fn=<DivBackward0>)
# EPOCHS: 88 ***************
# ERROR:88  tensor([[2.2157]], grad_fn=<DivBackward0>)
# EPOCHS: 89 ***************
# ERROR:89  tensor([[2.1951]], grad_fn=<DivBackward0>)
# EPOCHS: 90 ***************
# ERROR:90  tensor([[2.1749]], grad_fn=<DivBackward0>)
# EPOCHS: 91 ***************
# ERROR:91  tensor([[2.1552]], grad_fn=<DivBackward0>)
# EPOCHS: 92 ***************
# ERROR:92  tensor([[2.1358]], grad_fn=<DivBackward0>)
# EPOCHS: 93 ***************
# ERROR:93  tensor([[2.1167]], grad_fn=<DivBackward0>)
# EPOCHS: 94 ***************
# ERROR:94  tensor([[2.0981]], grad_fn=<DivBackward0>)
# EPOCHS: 95 ***************
# ERROR:95  tensor([[2.0798]], grad_fn=<DivBackward0>)
# EPOCHS: 96 ***************
# ERROR:96  tensor([[2.0618]], grad_fn=<DivBackward0>)
# EPOCHS: 97 ***************
# ERROR:97  tensor([[2.0442]], grad_fn=<DivBackward0>)
# EPOCHS: 98 ***************
# ERROR:98  tensor([[2.0269]], grad_fn=<DivBackward0>)
# EPOCHS: 99 ***************
# ERROR:99  tensor([[2.0099]], grad_fn=<DivBackward0>)
# EPOCHS: 100 ***************
# ERROR:100  tensor([[1.9932]], grad_fn=<DivBackward0>)

# %%
batch_size = 1
epochs = 100
a = neural_septuple(3,1)
loss = []
epoch = []

for i in range(epochs):
  print('EPOCHS: {} ***************'.format(i+1))
  count = 0
  error_count = 0
  for j in range(len(x)):
    a.create_state_vec(x[j],y[j])
    if i == 0 and j == 0:
      a.create_weight_matrix()
    pred = a.feed_forword(a.input_vec)
    error = (pred - a.state_vec).T @ a.p_out @ (pred - a.state_vec)
    #print(error)
    if (j+1) % batch_size == 0:
      error_count += error
      count += error
      error_count = error_count / batch_size
      #print('LOSS: ', error_count)
      a.backword_feed(error_count)
      error_count = 0
    else:
      with torch.no_grad():
        error_count += error
        count += error 
      #print(error_count)
  print('ERROR:{} '.format(i+1), count/5000)
  loss.append(count/5000)
  epoch.append(i)
# Out:
# EPOCHS: 1 ***************
# ERROR:1  tensor([[29.9142]], grad_fn=<DivBackward0>)
# EPOCHS: 2 ***************
# ERROR:2  tensor([[24.4103]], grad_fn=<DivBackward0>)
# EPOCHS: 3 ***************
# ERROR:3  tensor([[21.3143]], grad_fn=<DivBackward0>)
# EPOCHS: 4 ***************
# ERROR:4  tensor([[18.8491]], grad_fn=<DivBackward0>)
# EPOCHS: 5 ***************
# ERROR:5  tensor([[16.6531]], grad_fn=<DivBackward0>)
# EPOCHS: 6 ***************
# ERROR:6  tensor([[14.5175]], grad_fn=<DivBackward0>)
# EPOCHS: 7 ***************
# ERROR:7  tensor([[12.3260]], grad_fn=<DivBackward0>)
# EPOCHS: 8 ***************
# ERROR:8  tensor([[10.3409]], grad_fn=<DivBackward0>)
# EPOCHS: 9 ***************
# ERROR:9  tensor([[8.8628]], grad_fn=<DivBackward0>)
# EPOCHS: 10 ***************
# ERROR:10  tensor([[7.5952]], grad_fn=<DivBackward0>)
# EPOCHS: 11 ***************
# ERROR:11  tensor([[6.6159]], grad_fn=<DivBackward0>)
# EPOCHS: 12 ***************
# ERROR:12  tensor([[5.9337]], grad_fn=<DivBackward0>)
# EPOCHS: 13 ***************
# ERROR:13  tensor([[5.3866]], grad_fn=<DivBackward0>)
# EPOCHS: 14 ***************
# ERROR:14  tensor([[4.9275]], grad_fn=<DivBackward0>)
# EPOCHS: 15 ***************
# ERROR:15  tensor([[4.5717]], grad_fn=<DivBackward0>)
# EPOCHS: 16 ***************
# ERROR:16  tensor([[4.2914]], grad_fn=<DivBackward0>)
# EPOCHS: 17 ***************
# ERROR:17  tensor([[4.0535]], grad_fn=<DivBackward0>)
# EPOCHS: 18 ***************
# ERROR:18  tensor([[3.8380]], grad_fn=<DivBackward0>)
# EPOCHS: 19 ***************
# ERROR:19  tensor([[3.6335]], grad_fn=<DivBackward0>)
# EPOCHS: 20 ***************
# ERROR:20  tensor([[3.4395]], grad_fn=<DivBackward0>)
# EPOCHS: 21 ***************
# ERROR:21  tensor([[3.2638]], grad_fn=<DivBackward0>)
# EPOCHS: 22 ***************
# ERROR:22  tensor([[3.1109]], grad_fn=<DivBackward0>)
# EPOCHS: 23 ***************
# ERROR:23  tensor([[2.9778]], grad_fn=<DivBackward0>)
# EPOCHS: 24 ***************
# ERROR:24  tensor([[2.8595]], grad_fn=<DivBackward0>)
# EPOCHS: 25 ***************
# ERROR:25  tensor([[2.7528]], grad_fn=<DivBackward0>)
# EPOCHS: 26 ***************
# ERROR:26  tensor([[2.6556]], grad_fn=<DivBackward0>)
# EPOCHS: 27 ***************
# ERROR:27  tensor([[2.5666]], grad_fn=<DivBackward0>)
# EPOCHS: 28 ***************
# ERROR:28  tensor([[2.4847]], grad_fn=<DivBackward0>)
# EPOCHS: 29 ***************
# ERROR:29  tensor([[2.4090]], grad_fn=<DivBackward0>)
# EPOCHS: 30 ***************
# ERROR:30  tensor([[2.3386]], grad_fn=<DivBackward0>)
# EPOCHS: 31 ***************
# ERROR:31  tensor([[2.2730]], grad_fn=<DivBackward0>)
# EPOCHS: 32 ***************
# ERROR:32  tensor([[2.2116]], grad_fn=<DivBackward0>)
# EPOCHS: 33 ***************
# ERROR:33  tensor([[2.1538]], grad_fn=<DivBackward0>)
# EPOCHS: 34 ***************
# ERROR:34  tensor([[2.0992]], grad_fn=<DivBackward0>)
# EPOCHS: 35 ***************
# ERROR:35  tensor([[2.0475]], grad_fn=<DivBackward0>)
# EPOCHS: 36 ***************
# ERROR:36  tensor([[1.9982]], grad_fn=<DivBackward0>)
# EPOCHS: 37 ***************
# ERROR:37  tensor([[1.9512]], grad_fn=<DivBackward0>)
# EPOCHS: 38 ***************
# ERROR:38  tensor([[1.9061]], grad_fn=<DivBackward0>)
# EPOCHS: 39 ***************
# ERROR:39  tensor([[1.8627]], grad_fn=<DivBackward0>)
# EPOCHS: 40 ***************
# ERROR:40  tensor([[1.8207]], grad_fn=<DivBackward0>)
# EPOCHS: 41 ***************
# ERROR:41  tensor([[1.7802]], grad_fn=<DivBackward0>)
# EPOCHS: 42 ***************
# ERROR:42  tensor([[1.7408]], grad_fn=<DivBackward0>)
# EPOCHS: 43 ***************
# ERROR:43  tensor([[1.7025]], grad_fn=<DivBackward0>)
# EPOCHS: 44 ***************
# ERROR:44  tensor([[1.6653]], grad_fn=<DivBackward0>)
# EPOCHS: 45 ***************
# ERROR:45  tensor([[1.6292]], grad_fn=<DivBackward0>)
# EPOCHS: 46 ***************
# ERROR:46  tensor([[1.5941]], grad_fn=<DivBackward0>)
# EPOCHS: 47 ***************
# ERROR:47  tensor([[1.5602]], grad_fn=<DivBackward0>)
# EPOCHS: 48 ***************
# ERROR:48  tensor([[1.5274]], grad_fn=<DivBackward0>)
# EPOCHS: 49 ***************
# ERROR:49  tensor([[1.4959]], grad_fn=<DivBackward0>)
# EPOCHS: 50 ***************
# ERROR:50  tensor([[1.4655]], grad_fn=<DivBackward0>)
# EPOCHS: 51 ***************
# ERROR:51  tensor([[1.4364]], grad_fn=<DivBackward0>)
# EPOCHS: 52 ***************
# ERROR:52  tensor([[1.4085]], grad_fn=<DivBackward0>)
# EPOCHS: 53 ***************
# ERROR:53  tensor([[1.3819]], grad_fn=<DivBackward0>)
# EPOCHS: 54 ***************
# ERROR:54  tensor([[1.3564]], grad_fn=<DivBackward0>)
# EPOCHS: 55 ***************
# ERROR:55  tensor([[1.3321]], grad_fn=<DivBackward0>)
# EPOCHS: 56 ***************
# ERROR:56  tensor([[1.3090]], grad_fn=<DivBackward0>)
# EPOCHS: 57 ***************
# ERROR:57  tensor([[1.2868]], grad_fn=<DivBackward0>)
# EPOCHS: 58 ***************
# ERROR:58  tensor([[1.2657]], grad_fn=<DivBackward0>)
# EPOCHS: 59 ***************
# ERROR:59  tensor([[1.2455]], grad_fn=<DivBackward0>)
# EPOCHS: 60 ***************
# ERROR:60  tensor([[1.2262]], grad_fn=<DivBackward0>)
# EPOCHS: 61 ***************
# ERROR:61  tensor([[1.2076]], grad_fn=<DivBackward0>)
# EPOCHS: 62 ***************
# ERROR:62  tensor([[1.1898]], grad_fn=<DivBackward0>)
# EPOCHS: 63 ***************
# ERROR:63  tensor([[1.1726]], grad_fn=<DivBackward0>)
# EPOCHS: 64 ***************
# ERROR:64  tensor([[1.1561]], grad_fn=<DivBackward0>)
# EPOCHS: 65 ***************
# ERROR:65  tensor([[1.1401]], grad_fn=<DivBackward0>)
# EPOCHS: 66 ***************
# ERROR:66  tensor([[1.1246]], grad_fn=<DivBackward0>)
# EPOCHS: 67 ***************
# ERROR:67  tensor([[1.1097]], grad_fn=<DivBackward0>)
# EPOCHS: 68 ***************
# ERROR:68  tensor([[1.0951]], grad_fn=<DivBackward0>)
# EPOCHS: 69 ***************
# ERROR:69  tensor([[1.0811]], grad_fn=<DivBackward0>)
# EPOCHS: 70 ***************
# ERROR:70  tensor([[1.0673]], grad_fn=<DivBackward0>)
# EPOCHS: 71 ***************
# ERROR:71  tensor([[1.0540]], grad_fn=<DivBackward0>)
# EPOCHS: 72 ***************
# ERROR:72  tensor([[1.0409]], grad_fn=<DivBackward0>)
# EPOCHS: 73 ***************
# ERROR:73  tensor([[1.0282]], grad_fn=<DivBackward0>)
# EPOCHS: 74 ***************
# ERROR:74  tensor([[1.0157]], grad_fn=<DivBackward0>)
# EPOCHS: 75 ***************
# ERROR:75  tensor([[1.0035]], grad_fn=<DivBackward0>)
# EPOCHS: 76 ***************
# ERROR:76  tensor([[0.9915]], grad_fn=<DivBackward0>)
# EPOCHS: 77 ***************
# ERROR:77  tensor([[0.9798]], grad_fn=<DivBackward0>)
# EPOCHS: 78 ***************
# ERROR:78  tensor([[0.9682]], grad_fn=<DivBackward0>)
# EPOCHS: 79 ***************
# ERROR:79  tensor([[0.9568]], grad_fn=<DivBackward0>)
# EPOCHS: 80 ***************
# ERROR:80  tensor([[0.9456]], grad_fn=<DivBackward0>)
# EPOCHS: 81 ***************
# ERROR:81  tensor([[0.9345]], grad_fn=<DivBackward0>)
# EPOCHS: 82 ***************
# ERROR:82  tensor([[0.9237]], grad_fn=<DivBackward0>)
# EPOCHS: 83 ***************
# ERROR:83  tensor([[0.9130]], grad_fn=<DivBackward0>)
# EPOCHS: 84 ***************
# ERROR:84  tensor([[0.9024]], grad_fn=<DivBackward0>)
# EPOCHS: 85 ***************
# ERROR:85  tensor([[0.8920]], grad_fn=<DivBackward0>)
# EPOCHS: 86 ***************
# ERROR:86  tensor([[0.8819]], grad_fn=<DivBackward0>)
# EPOCHS: 87 ***************
# ERROR:87  tensor([[0.8719]], grad_fn=<DivBackward0>)
# EPOCHS: 88 ***************
# ERROR:88  tensor([[0.8621]], grad_fn=<DivBackward0>)
# EPOCHS: 89 ***************
# ERROR:89  tensor([[0.8525]], grad_fn=<DivBackward0>)
# EPOCHS: 90 ***************
# ERROR:90  tensor([[0.8432]], grad_fn=<DivBackward0>)
# EPOCHS: 91 ***************
# ERROR:91  tensor([[0.8341]], grad_fn=<DivBackward0>)
# EPOCHS: 92 ***************
# ERROR:92  tensor([[0.8252]], grad_fn=<DivBackward0>)
# EPOCHS: 93 ***************
# ERROR:93  tensor([[0.8165]], grad_fn=<DivBackward0>)
# EPOCHS: 94 ***************
# ERROR:94  tensor([[0.8080]], grad_fn=<DivBackward0>)
# EPOCHS: 95 ***************
# ERROR:95  tensor([[0.7997]], grad_fn=<DivBackward0>)
# EPOCHS: 96 ***************
# ERROR:96  tensor([[0.7916]], grad_fn=<DivBackward0>)
# EPOCHS: 97 ***************
# ERROR:97  tensor([[0.7837]], grad_fn=<DivBackward0>)
# EPOCHS: 98 ***************
# ERROR:98  tensor([[0.7760]], grad_fn=<DivBackward0>)
# EPOCHS: 99 ***************
# ERROR:99  tensor([[0.7685]], grad_fn=<DivBackward0>)
# EPOCHS: 100 ***************
# ERROR:100  tensor([[0.7611]], grad_fn=<DivBackward0>)

# %%
m = 1000
a.create_state_vec(x[m],y[m])

# %%
pred = a.p_out @ a.feed_forword(a.input_vec)

# %%
(pred - a.state_vec).T @ a.p_out @ (pred - a.state_vec)
# Out:
# tensor([[0.0141]], grad_fn=<MmBackward0>)

# %%
a.output_vec[-1], pred[-1]
# Out:
# (tensor([2.5948]), tensor([2.7135], grad_fn=<SelectBackward0>))

# %%
a.state_vec
# Out:
# tensor([[ 0.5135],
#         [ 0.5786],
#         [-0.5011],
#         [ 0.0000],
#         [ 0.0000],
#         [ 0.0000],
#         [ 0.0000],
#         [ 0.0000],
#         [ 0.0000],
#         [ 0.0000],
#         [ 0.0000],
#         [ 0.0000],
#         [ 0.0000],
#         [ 0.0000],
#         [ 0.0000],
#         [ 0.0000],
#         [ 0.0000],
#         [ 0.4315]])

# %%
 pred
# Out:
# tensor([[0.0000],
#         [0.0000],
#         [0.0000],
#         [0.0000],
#         [0.0000],
#         [0.0000],
#         [0.0000],
#         [0.0000],
#         [0.0000],
#         [0.0000],
#         [0.0000],
#         [0.0000],
#         [0.0000],
#         [0.0000],
#         [0.0000],
#         [0.0000],
#         [0.0000],
#         [0.3120]], grad_fn=<MmBackward0>)

# %%
pred
# Out:
# tensor([[ 0.7488],
#         [ 0.7169],
#         [-0.5766],
#         [ 1.8890],
#         [ 1.8890],
#         [ 2.7780],
#         [ 2.7780],
#         [ 3.5561]], grad_fn=<AddBackward0>)

# %%
a.loss(pred, a.state_vec)
# Out:
# tensor([[0.]], grad_fn=<MmBackward0>)

# %%
# Out:
# tensor([[1.0814]], grad_fn=<MmBackward0>)
